# %%
import numpy as np

# %%
import pandas as pd

# %%
file1 = pd.read_csv('/Users/petergeorge/Downloads/casestudy2/lab-customer-analysis-round-1-master/file1.csv')

# %%
file1.head()
# Out:
#   Customer          ST GENDER Education Customer Lifetime Value  Income  \
# 0  GS98873     Arizona      F  Bachelor              323912.47%   16061
# 1  CW49887  California      F    Master              462680.11%   79487
# 2  MY31220  California      F   College              899704.02%   54230
# 3  UH35128      Oregon      F   College             2580706.30%   71210
# 4  WH52799     Arizona      F   College              380812.21%   94903
#
#    Monthly Premium Auto Number of Open Complaints  Total Claim Amount  \
# 0                    88                    1/0/00               633.6
# 1                   114                    1/0/00               547.2
# 2                   112                    1/0/00               537.6
# 3                   214                    1/1/00              1027.2
# 4                    94                    1/0/00               451.2
#
#       Policy Type  Vehicle Class
# 0   Personal Auto  Four-Door Car
# 1    Special Auto            SUV
# ...

# %%
file1.shape
# Out:
# (996, 11)

# %%
file2 = pd.read_csv('/Users/petergeorge/Downloads/casestudy2/lab-customer-analysis-round-1-master/file2.csv')

# %%
file2.head()
# Out:
#   Customer          ST GENDER Education Customer Lifetime Value  Income  \
# 0  GS98873     Arizona      F  Bachelor              323912.47%   16061
# 1  CW49887  California      F    Master              462680.11%   79487
# 2  MY31220  California      F   College              899704.02%   54230
# 3  UH35128      Oregon      F   College             2580706.30%   71210
# 4  WH52799     Arizona      F   College              380812.21%   94903
#
#    Monthly Premium Auto Number of Open Complaints  Total Claim Amount  \
# 0                    88                    1/0/00               633.6
# 1                   114                    1/0/00               547.2
# 2                   112                    1/0/00               537.6
# 3                   214                    1/1/00              1027.2
# 4                    94                    1/0/00               451.2
#
#       Policy Type  Vehicle Class
# 0   Personal Auto  Four-Door Car
# 1    Special Auto            SUV
# ...

# %%
file2.shape
# Out:
# (996, 11)

# %%
file3 = pd.read_csv('/Users/petergeorge/Downloads/casestudy2/lab-customer-analysis-round-1-master/file3.csv')

# %%
file3.head()
# Out:
#   Customer       State  Customer Lifetime Value             Education Gender  \
# 0  SA25987  Washington              3479.137523  High School or Below      M
# 1  TB86706     Arizona              2502.637401                Master      M
# 2  ZL73902      Nevada              3265.156348              Bachelor      F
# 3  KX23516  California              4455.843406  High School or Below      F
# 4  FN77294  California              7704.958480  High School or Below      M
#
#    Income  Monthly Premium Auto  Number of Open Complaints    Policy Type  \
# 0       0                   104                          0  Personal Auto
# 1       0                    66                          0  Personal Auto
# 2   25820                    82                          0  Personal Auto
# 3       0                   121                          0  Personal Auto
# 4   30366                   101                          2  Personal Auto
#
#    Total Claim Amount  Vehicle Class
# ...

# %%
file3.shape
# Out:
# (7070, 11)

# %%
# Standardize header names. File 1

# %%
print(file1.columns)
# Out:
# Index(['Customer', 'ST', 'GENDER', 'Education', 'Customer Lifetime Value',
#        'Income', 'Monthly Premium Auto', 'Number of Open Complaints',
#        'Total Claim Amount', 'Policy Type', 'Vehicle Class'],
#       dtype='object')

# %%
cols = []
for i in range(len(file1.columns)):
    cols.append(file1.columns[i].lower().replace(' ',' '))
file1.columns = cols
print(file1.columns)
# Out:
# Index(['customer', 'st', 'gender', 'education', 'customer lifetime value',
#        'income', 'monthly premium auto', 'number of open complaints',
#        'total claim amount', 'policy type', 'vehicle class'],
#       dtype='object')

# %%
# Standardize header names. File 2

# %%
print(file2.columns)
# Out:
# Index(['customer', 'st', 'gender', 'education', 'customer lifetime value',
#        'income', 'monthly premium auto', 'number of open complaints',
#        'total claim amount', 'policy type', 'vehicle class'],
#       dtype='object')

# %%
cols = []
for i in range(len(file2.columns)):
    cols.append(file2.columns[i].lower().replace(' ', ' '))
file2.columns = cols
print(file2.columns)
# Out:
# Index(['customer', 'st', 'gender', 'education', 'customer lifetime value',
#        'income', 'monthly premium auto', 'number of open complaints',
#        'total claim amount', 'policy type', 'vehicle class'],
#       dtype='object')

# %%
# Standardize header names. File 3

# %%
print(file3.columns)
# Out:
# Index(['Customer', 'State', 'Customer Lifetime Value', 'Education', 'Gender',
#        'Income', 'Monthly Premium Auto', 'Number of Open Complaints',
#        'Policy Type', 'Total Claim Amount', 'Vehicle Class'],
#       dtype='object')

# %%
cols = []
for i in range(len(file3.columns)):
    cols.append(file3.columns[i].lower().replace(' ', ' '))
file3.columns = cols
print(file3.columns)
# Out:
# Index(['customer', 'state', 'customer lifetime value', 'education', 'gender',
#        'income', 'monthly premium auto', 'number of open complaints',
#        'policy type', 'total claim amount', 'vehicle class'],
#       dtype='object')

# %%
# Rearrange the columns in the dataframe as needed

# %%
file3 = file3.rename(columns={'state':'st'})

# %%
file2 = file2[file1.columns]
file2.head()
# Out:
#   customer          st gender education customer lifetime value  income  \
# 0  GS98873     Arizona      F  Bachelor              323912.47%   16061
# 1  CW49887  California      F    Master              462680.11%   79487
# 2  MY31220  California      F   College              899704.02%   54230
# 3  UH35128      Oregon      F   College             2580706.30%   71210
# 4  WH52799     Arizona      F   College              380812.21%   94903
#
#    monthly premium auto number of open complaints  total claim amount  \
# 0                    88                    1/0/00               633.6
# 1                   114                    1/0/00               547.2
# 2                   112                    1/0/00               537.6
# 3                   214                    1/1/00              1027.2
# 4                    94                    1/0/00               451.2
#
#       policy type  vehicle class
# 0   Personal Auto  Four-Door Car
# 1    Special Auto            SUV
# ...

# %%
file3 = file3[file1.columns]
file3.head()
# Out:
#   customer          st gender             education  customer lifetime value  \
# 0  SA25987  Washington      M  High School or Below              3479.137523
# 1  TB86706     Arizona      M                Master              2502.637401
# 2  ZL73902      Nevada      F              Bachelor              3265.156348
# 3  KX23516  California      F  High School or Below              4455.843406
# 4  FN77294  California      M  High School or Below              7704.958480
#
#    income  monthly premium auto  number of open complaints  \
# 0       0                   104                          0
# 1       0                    66                          0
# 2   25820                    82                          0
# 3       0                   121                          0
# 4   30366                   101                          2
#
#    total claim amount    policy type  vehicle class
# 0          499.200000  Personal Auto   Two-Door Car
# ...

# %%
# Concatenate the three dataframes

# %%
data = pd.DataFrame(columns=column_names)
data
# Out:
# Empty DataFrame
# Columns: [customer, st, gender, education, customer lifetime value, income, monthly premium auto, number of open complaints, total claim amount, policy type, vehicle class]
# Index: []

# %%
data = pd.concat([data,file1, file2, file3], axis=0)

# %%
data.shape
# Out:
# (9062, 11)

# %%
# numerical columns and understand the meaning of all columns

# %%
data.select_dtypes('float')
# Out:
#       total claim amount
# 0             633.600000
# 1             547.200000
# 2             537.600000
# 3            1027.200000
# 4             451.200000
# ...                  ...
# 7065          198.234764
# 7066          379.200000
# 7067          790.784983
# 7068          691.200000
# 7069          369.600000
#
# [9062 rows x 1 columns]

# %%
# categorical columns and understand the meaning of all columns

# %%
data.select_dtypes('object')
# Out:
#      customer          st gender education customer lifetime value income  \
# 0     GS98873     Arizona      F  Bachelor              323912.47%  16061
# 1     CW49887  California      F    Master              462680.11%  79487
# 2     MY31220  California      F   College              899704.02%  54230
# 3     UH35128      Oregon      F   College             2580706.30%  71210
# 4     WH52799     Arizona      F   College              380812.21%  94903
# ...       ...         ...    ...       ...                     ...    ...
# 7065  LA72316  California      M  Bachelor                   23406  71941
# 7066  PK87824  California      F   College                 3096.51  21604
# 7067  TD14365  California      M  Bachelor                 8163.89      0
# 7068  UP19263  California      M   College                 7524.44  21941
# 7069  Y167826  California      M   College                 2611.84      0
#
#      monthly premium auto number of open complaints     policy type  \
# ...

# %%
# Delete the column education and the number of open complaints from the dataframe

# %%
data = data.drop(['education'], axis=1)
data
# Out:
#      customer          st gender customer lifetime value income  \
# 7     HW62747      Oregon      M              229837.92%      0
# 26    VL34577      Oregon      F              259618.52%      0
# 30    TJ11671      Oregon      F              401521.45%      0
# 32    XD19546  California      F              816068.98%      0
# 34    SW57539  California      F              871492.21%      0
# ...       ...         ...    ...                     ...    ...
# 7059  WZ45103  California      F                 5678.05      0
# 7061  RX91025  California      M                 19872.3      0
# 7062  AC13887  California      M                    4629      0
# 7067  TD14365  California      M                 8163.89      0
# 7069  Y167826  California      M                 2611.84      0
#
#      monthly premium auto number of open complaints  total claim amount  \
# 7                      63                    1/0/00          302.400000
# ...

# %%
data = data.drop(['number of open complaints'], axis=1)
data
# Out:
#      customer          st gender customer lifetime value income  \
# 7     HW62747      Oregon      M              229837.92%      0
# 26    VL34577      Oregon      F              259618.52%      0
# 30    TJ11671      Oregon      F              401521.45%      0
# 32    XD19546  California      F              816068.98%      0
# 34    SW57539  California      F              871492.21%      0
# ...       ...         ...    ...                     ...    ...
# 7059  WZ45103  California      F                 5678.05      0
# 7061  RX91025  California      M                 19872.3      0
# 7062  AC13887  California      M                    4629      0
# 7067  TD14365  California      M                 8163.89      0
# 7069  Y167826  California      M                 2611.84      0
#
#      monthly premium auto  total claim amount     policy type  vehicle class
# 7                      63          302.400000  Corporate Auto  Four-Door Car
# ...

# %%
# Correct the values in the column customer lifetime value. They are given as a percent, so multiply them by 100 and change dtype to numerical type.

# %%
data['customer lifetime value'] = data['customer lifetime value']*100

# %%
data['customer lifetime value'] =  pd.to_numeric(data['customer lifetime value'], errors='coerce')

# %%
data['customer lifetime value']
# Out:
# 7                NaN
# 26               NaN
# 30               NaN
# 32               NaN
# 34               NaN
#             ...
# 7059    5.678050e+07
# 7061    1.987226e+08
# 7062    4.628995e+07
# 7067    8.163890e+07
# 7069    2.611837e+07
# Name: customer lifetime value, Length: 2042, dtype: float64

# %%
# Check for duplicate rows in the data and remove if any.

# %%
data.shape
# Out:
# (9062, 11)

# %%
data = data.drop_duplicates()

# %%
data.shape
# Out:
# (8066, 11)

# %%
# Filter out the data for customers who have an income of 0 or less

# %%
data = data[data['income']<=0]

# %%
data
# Out:
#      customer          st gender             education  \
# 7     HW62747      Oregon      M               College
# 26    VL34577      Oregon      F  High School or Below
# 30    TJ11671      Oregon      F              Bachelor
# 32    XD19546  California      F  High School or Below
# 34    SW57539  California      F               College
# ...       ...         ...    ...                   ...
# 7059  WZ45103  California      F              Bachelor
# 7061  RX91025  California      M  High School or Below
# 7062  AC13887  California      M              Bachelor
# 7067  TD14365  California      M              Bachelor
# 7069  Y167826  California      M               College
#
#      customer lifetime value income monthly premium auto  \
# 7                 229837.92%      0                   63
# 26                259618.52%      0                   72
# 30                401521.45%      0                  109
# 32                816068.98%      0                  109
# ...
